# %% [markdown]
# ## DATABASE & ANALYTICS PROGRAMMING
# ### Irelands accommodation activities and attractions data visualization

# %%
#Import all the required librabries
# !pip install "pymongo[srv]"
import urllib.request
from pymongo import MongoClient
import json
import pymongo
import numpy as np
import pandas as pd
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\wwwde\pthon 10\lib\site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\wwwde\pthon 10\lib\site-packages (from pymongo[srv]) (2.3.0)

# %% [markdown]
# ## Fetch all the required data from the web

# %%
#created function with "name" as API call request type name and "number" as the pages
def get_all_details(name,number):
    #total data in activities=6115,accommodation=2397,attractions=1556
    base_url = "https://failteireland.azure-api.net/opendata-api/v1/{}subscription-key=&search=*&$skip={}"
    acc_url = base_url.format(name, number)
    
    try:
        with urllib.request.urlopen(acc_url) as response:
            
            return json.load(response)
    except urllib.error.URLError as e:
        print("The API URL is invalid."+e)
    except json.JSONDecodeError:
        print("Error decoding JSON response")
        return {}

# %%
#remote mongoDB
client = MongoClient("mongodb+srv://AdminDap:admin003@cluster3.oqbqjxz.mongodb.net/test")
client.test
db = client['dap_project']
acc_data = db['accommodation-collection']
attrac_data = db['attractions-collection']
acti_data = db['activities-collection']

# %%
def upload_data(data_type,ALL_DATA):
    if data_type =="accommodation" and len(ALL_DATA) != 0:
        for i in range (0 , len(ALL_DATA["results"])):
            acc_data.insert_one(ALL_DATA["results"][i])
    elif data_type =="attractions" and len(ALL_DATA) != 0:
        for i in range (0 , len(ALL_DATA["results"])):
            attrac_data.insert_one(ALL_DATA["results"][i])
    elif data_type =="activities" and len(ALL_DATA) != 0:
        for i in range (0 , len(ALL_DATA["results"])):
            acti_data.insert_one(ALL_DATA["results"][i])

# %%
for dat in np.arange(0,2400,50):
    print(dat)
    upload_data("accommodation",get_all_details("accommodation?",dat))
    time.sleep(10)

# %%
for dat in np.arange(0,1600,50):
    print(dat)
    upload_data("attractions",get_all_details("attractions?",dat))
    time.sleep(10)

# %%
for dat in np.arange(0,6150,50):
    print(dat)
    upload_data("activities",get_all_details("activities?",dat))
    time.sleep(10)

# %%
attraction_df = pd.DataFrame(list(attrac_data.find()))
attraction_df.shape
# Out:
# (1506, 10)

# %%
attraction_df.head()
# Out:
#                         _id           @context  \
# 0  64342a803594cb2a7438641e  http://schema.org
# 1  64342a803594cb2a7438641f  http://schema.org
# 2  64342a813594cb2a74386420  http://schema.org
# 3  64342a813594cb2a74386421  http://schema.org
# 4  64342a813594cb2a74386422  http://schema.org
#
#                                                @type  \
# 0                            [LocalBusiness, Museum]
# 1  [LocalBusiness, FoodEstablishment, TravelAgenc...
# 2  [LocalBusiness, TouristAttraction, LandmarksOr...
# 3  [LocalBusiness, TouristAttraction, LandmarksOr...
# 4  [LocalBusiness, TouristAttraction, LandmarksOr...
#
#                                    name  \
# 0                Michael J Quill Centre
# 1  Sonairte The National Ecology Centre
# 2                       Clonmore Castle
# 3                    Dún Na Séad Castle
# 4                          Conna Castle
#
#                                                  url  \
# 0    http://www.historic-ireland.com/places/778.html
# 1                             http://www.sonairte.ie
# 2  http://www.megalithicireland.com/Clonmore%20Ca...
# 3                    https://www.baltimorecastle.ie/
# 4                https://www.castles.nl/conna-castle
#
#                                                  geo      telephone  \
# 0  {'@type': 'GeoCoordinates', 'longitude': -9.46...  +353646685511
# 1  {'@type': 'GeoCoordinates', 'longitude': -6.25...  +353419827572
# 2  {'@type': 'GeoCoordinates', 'longitude': -6.57...
# 3  {'@type': 'GeoCoordinates', 'longitude': -9.37...    +3532820735
# 4  {'@type': 'GeoCoordinates', 'longitude': -8.10...  +353862149601
#
#                                              address  \
# 0  {'@type': 'PostalAddress', 'addressLocality': ...
# 1  {'@type': 'PostalAddress', 'addressLocality': ...
# 2  {'@type': 'PostalAddress', 'addressLocality': ...
# 3  {'@type': 'PostalAddress', 'addressLocality': ...
# 4  {'@type': 'PostalAddress', 'addressLocality': ...
#
#                                                image  \
# 0  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 1  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 2  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 3  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 4  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
#
#                                                 tags
# 0     [Activity, Attraction, Museums and Attraction]
# 1  [Activity, Agriculture, Nature and Wildlife, F...
# 2  [Activity, Castle, Attraction, Historic Houses...
# 3  [Activity, Attraction, Historic Houses and Cas...
# 4  [Activity, Castle, Attraction, Historic Houses...

# %%
df = pd.json_normalize(list(attrac_data.find()),max_level=1)
df = df.drop(["_id","@context", "url", "image.@type", "image.caption", "image.url", "geo.@type", "address.@type", "telephone"], axis=1)

# flatten @type and tags data
df['@type'] = df['@type'].apply(lambda x: {t: True for t in x})
df['tags'] = df['tags'].apply(lambda x: {t: True for t in x})

# convert @type and tags columns to separate columns with boolean values
df = pd.concat([df.drop(['@type', 'tags'], axis=1), df['@type'].apply(pd.Series).fillna(False), df['tags'].apply(pd.Series).fillna(False)], axis=1)
df = df.rename(columns={
    "name": "Name",
    "geo.longitude": "Longitude",
    "geo.latitude": "Latitude",
    "address.addressLocality": "Locality",
    "address.addressRegion": "Region",
    "address.addressCountry": "Country"
})
df.head()
# Out:
#                                    Name  Longitude   Latitude   Locality  \
# 0                Michael J Quill Centre  -9.461430  51.902656  Kilgarvan
# 1  Sonairte The National Ecology Centre  -6.257022  53.678076    Laytown
# 2                       Clonmore Castle  -6.575125  52.828286   Clonmore
# 3                    Dún Na Séad Castle  -9.373102  51.483571  Baltimore
# 4                          Conna Castle  -8.101655  52.094521      Conna
#
#    Region              Country  LocalBusiness  Museum  FoodEstablishment  \
# 0   Kerry  Republic of Ireland           True    True              False
# 1   Meath  Republic of Ireland           True   False               True
# 2  Carlow  Republic of Ireland           True   False              False
# 3    Cork  Republic of Ireland           True   False              False
# 4    Cork  Republic of Ireland           True   False              False
#
#    TravelAgency  ...  Cookery  Adventure Park  Zip Lining  Marina  Pampering  \
# 0         False  ...    False           False       False   False      False
# 1          True  ...    False           False       False   False      False
# 2         False  ...    False           False       False   False      False
# 3         False  ...    False           False       False   False      False
# 4         False  ...    False           False       False   False      False
#
#    Health Farm  Spa and Wellness  Specialised Retreat    Spa  Bike Rental
# 0        False             False                False  False        False
# 1        False             False                False  False        False
# 2        False             False                False  False        False
# 3        False             False                False  False        False
# 4        False             False                False  False        False
#
# [5 rows x 128 columns]

# %%
################################################################################
acc_df = pd.DataFrame(list(acc_data.find()))
acc_df.shape
# Out:
# (2247, 10)

# %%
acc_df.head()
# Out:
#                         _id           @context  \
# 0  643063d02c0b26644db2d528  http://schema.org
# 1  643063d02c0b26644db2d529  http://schema.org
# 2  643063d02c0b26644db2d52a  http://schema.org
# 3  643063d02c0b26644db2d52b  http://schema.org
# 4  643063d02c0b26644db2d52c  http://schema.org
#
#                               @type                             name  \
# 0            [Hotel, LocalBusiness]                    Taravie Hotel
# 1            [Hotel, LocalBusiness]  Adare Manor Hotel & Golf Resort
# 2           [Hostel, LocalBusiness]         Courtbrack Accommodation
# 3  [BedAndBreakfast, LocalBusiness]                       Glencarrig
# 4  [BedAndBreakfast, LocalBusiness]                     Mevagh House
#
#                                                  url  \
# 0  https://www.facebook.com/pages/Taravie-Hotel/2...
# 1                        https://www.adaremanor.com/
# 2
# 3                https://www.facebook.com/glencarrig
# 4                         http://www.mevaghhouse.com
#
#                                                  geo         telephone  \
# 0  {'@type': 'GeoCoordinates', 'longitude': -6.22...  +353(0)539425208
# 1  {'@type': 'GeoCoordinates', 'longitude': -8.77...      +35361605200
# 2  {'@type': 'GeoCoordinates', 'longitude': -8.64...   +353(0)61302500
# 3  {'@type': 'GeoCoordinates', 'longitude': -9.72...  +353(0)659058209
# 4  {'@type': 'GeoCoordinates', 'longitude': -7.78...  +353(0)749154708
#
#                                              address  \
# 0  {'@type': 'PostalAddress', 'addressLocality': ...
# 1  {'@type': 'PostalAddress', 'addressLocality': ...
# 2  {'@type': 'PostalAddress', 'addressLocality': ...
# 3  {'@type': 'PostalAddress', 'addressLocality': ...
# 4  {'@type': 'PostalAddress', 'addressLocality': ...
#
#                                                image  \
# 0  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 1  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 2  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 3  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
# 4  {'@type': 'ImageObject', 'caption': 'Fáilte Ir...
#
#                                                 tags
# 0  [Accommodation, Hotel, Follow the Shamrock, St...
# 1  [Accommodation, Hotel, Follow the Shamrock, St...
# 2  [Accommodation, Hostel, Follow the Shamrock, S...
# 3  [Accommodation, B&B, Follow the Shamrock, Stan...
# 4  [Accommodation, B&B, Follow the Shamrock, Stan...

# %%
longitude,latitude = [],[]
def createDf(data): #calling function
    print(data)

# %%
test_Dataset = acc_df['geo']
for i in range (0,len(test_Dataset)):
            longitude.append(test_Dataset.get(i).get('longitude'))
            latitude.append(test_Dataset.get(i).get('latitude'))
data={
        'longitude':longitude,
        'latitude':latitude
}
geo_Data = pd.DataFrame(data)
geo_Data.head(10)
# Out:
#    longitude   latitude
# 0  -6.228038  52.645326
# 1  -8.777826  52.564189
# 2  -8.646733  52.655444
# 3  -9.721323  52.592004
# 4  -7.785543  55.176324
# 5 -10.241932  51.933964
# 6  -9.221627  53.572568
# 7  -9.829117  53.768128
# 8  -6.611201  53.231344
# 9  -6.579391  52.385478

# %%
locality,region,country = [],[],[]
def createDf(data): #calling function
    print(data)
test_Dataset = acc_df['address']
for i in range (0,len(test_Dataset)):
            locality.append(test_Dataset.get(i).get('addressLocality'))
            region.append(test_Dataset.get(i).get('addressRegion'))
            country.append(test_Dataset.get(i).get('addressCountry'))
data={
        'Locality':locality,
        'Region':region,
        'Country':country
}
location_Data = pd.DataFrame(data)
location_Data.head(20)
location_Data.shape
# Out:
# (2247, 3)

# %%
main_data = pd.concat([location_Data,geo_Data],axis=1)
main_data.tail(10)
# Out:
#                 Locality     Region              Country  longitude   latitude
# 2237        Lisdoonvarna      Clare  Republic of Ireland  -9.289173  53.029319
# 2238              Fermoy       Cork  Republic of Ireland  -8.275465  52.140915
# 2239               Balla       Mayo  Republic of Ireland  -9.142153  53.833305
# 2240         Dublin City     Dublin  Republic of Ireland  -6.236170  53.348417
# 2241           Ashbourne      Meath  Republic of Ireland  -6.429597  53.510127
# 2242  Carrick-on-Shannon    Leitrim  Republic of Ireland  -8.095886  53.943717
# 2243          Skibbereen       Cork  Republic of Ireland  -9.130571  51.558125
# 2244          Carndonagh    Donegal  Republic of Ireland  -7.224352  55.242060
# 2245              Mallow       Cork  Republic of Ireland  -8.656962  52.185199
# 2246               Cahir  Tipperary  Republic of Ireland  -7.915593  52.377426

# %%
# we split the column geolocation to lattitude and longitude for future reference
#defining
type0 = [] 

#looping the Geo column to fetch the data
for data in acc_df["@type"]:
    type0.append(data[0]) #feath the data from first index
#placing the data in to the original dataframe as two columns and dropping the old colume geolocation
main_data['Type of Hotel'] = type0 #adding values to column
main_data['Hotel Name'] = acc_df["name"]
main_data['Url of Accomodation'] = acc_df["url"]
main_data.head(10)
# Out:
#         Locality    Region              Country  longitude   latitude  \
# 0       Courtown   Wexford  Republic of Ireland  -6.228038  52.645326
# 1          Adare  Limerick  Republic of Ireland  -8.777826  52.564189
# 2  Limerick City  Limerick  Republic of Ireland  -8.646733  52.655444
# 3    Carrigaholt     Clare  Republic of Ireland  -9.721323  52.592004
# 4      Carrigart   Donegal  Republic of Ireland  -7.785543  55.176324
# 5    Cahersiveen     Kerry  Republic of Ireland -10.241932  51.933964
# 6     Ballinrobe      Mayo  Republic of Ireland  -9.221627  53.572568
# 7     Louisburgh      Mayo  Republic of Ireland  -9.829117  53.768128
# 8           Naas   Kildare  Republic of Ireland  -6.611201  53.231344
# 9       Killurin   Wexford  Republic of Ireland  -6.579391  52.385478
#
#      Type of Hotel                       Hotel Name  \
# 0            Hotel                    Taravie Hotel
# 1            Hotel  Adare Manor Hotel & Golf Resort
# 2           Hostel         Courtbrack Accommodation
# 3  BedAndBreakfast                       Glencarrig
# 4  BedAndBreakfast                     Mevagh House
# 5  BedAndBreakfast                    Cul Draiochta
# 6  BedAndBreakfast               Templecarrig House
# 7  BedAndBreakfast                    Cuaneen House
# 8  LodgingBusiness                  Ashwell Cottage
# 9  BedAndBreakfast                   Killurin Lodge
#
#                                  Url of Accomodation
# 0  https://www.facebook.com/pages/Taravie-Hotel/2...
# 1                        https://www.adaremanor.com/
# 2
# 3                https://www.facebook.com/glencarrig
# 4                         http://www.mevaghhouse.com
# 5
# 6                 https://www.templecarrighouse.com/
# 7                        http://www.cuaneenhouse.com
# 8                      http://www.ashwellcottage.com
# 9                       http://www.killurinlodge.com

# %%
data7 = pd.DataFrame(list(acc_df['tags']))
data7 = data7.drop([4,5,6,7],axis=1)
data7
# Out:
#                   0                            1                    2  \
# 0     Accommodation                        Hotel  Follow the Shamrock
# 1     Accommodation                        Hotel  Follow the Shamrock
# 2     Accommodation                       Hostel  Follow the Shamrock
# 3     Accommodation                          B&B  Follow the Shamrock
# 4     Accommodation                          B&B  Follow the Shamrock
# ...             ...                          ...                  ...
# 2242  Accommodation  Self Catering Accommodation     Welcome Standard
# 2243  Accommodation                          B&B     Welcome Standard
# 2244  Accommodation  Self Catering Accommodation                 None
# 2245  Accommodation                        Hotel  Follow the Shamrock
# 2246  Accommodation                          B&B  Follow the Shamrock
#
#                                  3
# 0                         Standard
# 1                         Standard
# 2                         Standard
# 3                         Standard
# 4                         Standard
# ...                            ...
# 2242  Ireland's Hidden Hearthlands
# 2243                          None
# 2244                          None
# 2245                      Standard
# 2246                      Standard
#
# [2247 rows x 4 columns]

# %%
data7.rename(columns={data7.columns[0]: 'Tag_0'},inplace=True)
data7.rename(columns={data7.columns[1]: 'Tag_1'},inplace=True)
data7.rename(columns={data7.columns[2]: 'Tag_2'},inplace=True)
data7.rename(columns={data7.columns[3]: 'Tag_3'},inplace=True)

# %%
data7
# Out:
#               Tag_0                        Tag_1                Tag_2  \
# 0     Accommodation                        Hotel  Follow the Shamrock
# 1     Accommodation                        Hotel  Follow the Shamrock
# 2     Accommodation                       Hostel  Follow the Shamrock
# 3     Accommodation                          B&B  Follow the Shamrock
# 4     Accommodation                          B&B  Follow the Shamrock
# ...             ...                          ...                  ...
# 2242  Accommodation  Self Catering Accommodation     Welcome Standard
# 2243  Accommodation                          B&B     Welcome Standard
# 2244  Accommodation  Self Catering Accommodation                 None
# 2245  Accommodation                        Hotel  Follow the Shamrock
# 2246  Accommodation                          B&B  Follow the Shamrock
#
#                              Tag_3
# 0                         Standard
# 1                         Standard
# 2                         Standard
# 3                         Standard
# 4                         Standard
# ...                            ...
# 2242  Ireland's Hidden Hearthlands
# 2243                          None
# 2244                          None
# 2245                      Standard
# 2246                      Standard
#
# [2247 rows x 4 columns]

# %%
main_data
# Out:
#                 Locality     Region              Country  longitude  \
# 0               Courtown    Wexford  Republic of Ireland  -6.228038
# 1                  Adare   Limerick  Republic of Ireland  -8.777826
# 2          Limerick City   Limerick  Republic of Ireland  -8.646733
# 3            Carrigaholt      Clare  Republic of Ireland  -9.721323
# 4              Carrigart    Donegal  Republic of Ireland  -7.785543
# ...                  ...        ...                  ...        ...
# 2242  Carrick-on-Shannon    Leitrim  Republic of Ireland  -8.095886
# 2243          Skibbereen       Cork  Republic of Ireland  -9.130571
# 2244          Carndonagh    Donegal  Republic of Ireland  -7.224352
# 2245              Mallow       Cork  Republic of Ireland  -8.656962
# 2246               Cahir  Tipperary  Republic of Ireland  -7.915593
#
#        latitude    Type of Hotel                                  Hotel Name  \
# 0     52.645326            Hotel                               Taravie Hotel
# 1     52.564189            Hotel             Adare Manor Hotel & Golf Resort
# 2     52.655444           Hostel                    Courtbrack Accommodation
# 3     52.592004  BedAndBreakfast                                  Glencarrig
# 4     55.176324  BedAndBreakfast                                Mevagh House
# ...         ...              ...                                         ...
# 2242  53.943717  LodgingBusiness                       Carrick Self Catering
# 2243  51.558125  BedAndBreakfast  Shearwater Country House and Accommodation
# 2244  55.242060  LodgingBusiness         Inishowen Artists' Retreat & Studio
# 2245  52.185199            Hotel         Springfort Hall Country House Hotel
# 2246  52.377426  BedAndBreakfast                       Ard na Greine (Cahir)
#
#                                     Url of Accomodation
# 0     https://www.facebook.com/pages/Taravie-Hotel/2...
# 1                           https://www.adaremanor.com/
# 2
# 3                   https://www.facebook.com/glencarrig
# 4                            http://www.mevaghhouse.com
# ...                                                 ...
# 2242                https://www.carrickselfcatering.ie/
# 2243                        http://shearwaterbandb.com/
# 2244                       https://artstaysdonegal.com/
# 2245                   https://www.springfort-hall.com/
# 2246                          http://www.ardnagreine.eu
#
# [2247 rows x 8 columns]

# %%
results = pd.concat([main_data,data7],axis=1,join='inner')
results
# Out:
#                 Locality     Region              Country  longitude  \
# 0               Courtown    Wexford  Republic of Ireland  -6.228038
# 1                  Adare   Limerick  Republic of Ireland  -8.777826
# 2          Limerick City   Limerick  Republic of Ireland  -8.646733
# 3            Carrigaholt      Clare  Republic of Ireland  -9.721323
# 4              Carrigart    Donegal  Republic of Ireland  -7.785543
# ...                  ...        ...                  ...        ...
# 2242  Carrick-on-Shannon    Leitrim  Republic of Ireland  -8.095886
# 2243          Skibbereen       Cork  Republic of Ireland  -9.130571
# 2244          Carndonagh    Donegal  Republic of Ireland  -7.224352
# 2245              Mallow       Cork  Republic of Ireland  -8.656962
# 2246               Cahir  Tipperary  Republic of Ireland  -7.915593
#
#        latitude    Type of Hotel                                  Hotel Name  \
# 0     52.645326            Hotel                               Taravie Hotel
# 1     52.564189            Hotel             Adare Manor Hotel & Golf Resort
# 2     52.655444           Hostel                    Courtbrack Accommodation
# 3     52.592004  BedAndBreakfast                                  Glencarrig
# 4     55.176324  BedAndBreakfast                                Mevagh House
# ...         ...              ...                                         ...
# 2242  53.943717  LodgingBusiness                       Carrick Self Catering
# 2243  51.558125  BedAndBreakfast  Shearwater Country House and Accommodation
# 2244  55.242060  LodgingBusiness         Inishowen Artists' Retreat & Studio
# 2245  52.185199            Hotel         Springfort Hall Country House Hotel
# 2246  52.377426  BedAndBreakfast                       Ard na Greine (Cahir)
#
#                                     Url of Accomodation          Tag_0  \
# 0     https://www.facebook.com/pages/Taravie-Hotel/2...  Accommodation
# 1                           https://www.adaremanor.com/  Accommodation
# 2                                                        Accommodation
# 3                   https://www.facebook.com/glencarrig  Accommodation
# 4                            http://www.mevaghhouse.com  Accommodation
# ...                                                 ...            ...
# 2242                https://www.carrickselfcatering.ie/  Accommodation
# 2243                        http://shearwaterbandb.com/  Accommodation
# 2244                       https://artstaysdonegal.com/  Accommodation
# 2245                   https://www.springfort-hall.com/  Accommodation
# 2246                          http://www.ardnagreine.eu  Accommodation
#
#                             Tag_1                Tag_2  \
# 0                           Hotel  Follow the Shamrock
# 1                           Hotel  Follow the Shamrock
# 2                          Hostel  Follow the Shamrock
# 3                             B&B  Follow the Shamrock
# 4                             B&B  Follow the Shamrock
# ...                           ...                  ...
# 2242  Self Catering Accommodation     Welcome Standard
# 2243                          B&B     Welcome Standard
# 2244  Self Catering Accommodation                 None
# 2245                        Hotel  Follow the Shamrock
# 2246                          B&B  Follow the Shamrock
#
#                              Tag_3
# 0                         Standard
# 1                         Standard
# 2                         Standard
# 3                         Standard
# 4                         Standard
# ...                            ...
# 2242  Ireland's Hidden Hearthlands
# 2243                          None
# 2244                          None
# 2245                      Standard
# 2246                      Standard
#
# [2247 rows x 12 columns]
